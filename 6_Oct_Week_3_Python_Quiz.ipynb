# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.display import Image

# %%
df = pd.read_csv('Placement_Data.csv')

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
df.shape
# Out:
# (215, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gender          215 non-null    object
#  1   ssc_p           215 non-null    float64
#  2   ssc_b           215 non-null    object
#  3   hsc_p           215 non-null    float64
#  4   hsc_b           215 non-null    object
#  5   hsc_s           215 non-null    object
#  6   degree_p        215 non-null    float64
#  7   degree_t        215 non-null    object
#  8   workex          215 non-null    object
#  9   etest_p         215 non-null    float64
#  10  specialisation  215 non-null    object
#  11  mba_p           215 non-null    float64
#  12  status          215 non-null    object
# dtypes: float64(5), object(8)
# memory usage: 22.0+ KB

# %%
len(df[df['status'] == 'Placed'])
# Out:
# 148

# %%
df.describe()
# Out:
#             ssc_p       hsc_p    degree_p     etest_p       mba_p
# count  215.000000  215.000000  215.000000  215.000000  215.000000
# mean    67.303395   66.333163   66.370186   72.100558   62.278186
# std     10.827205   10.897509    7.358743   13.275956    5.833385
# min     40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     60.600000   60.900000   61.000000   60.000000   57.945000
# 50%     67.000000   65.000000   66.000000   71.000000   62.000000
# 75%     75.700000   73.000000   72.000000   83.500000   66.255000
# max     89.400000   97.700000   91.000000   98.000000   77.890000

# %%
sns.histplot(data=df,x='ssc_p')
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %%
sns.countplot(x = 'hsc_s', data = df, hue = 'status');

# %%
df.head(5)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
# 3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech
# 4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p      status
# 0     No     55.0         Mkt&HR  58.80      Placed
# 1    Yes     86.5        Mkt&Fin  66.28      Placed
# 2     No     75.0        Mkt&Fin  57.80      Placed
# 3     No     66.0         Mkt&HR  59.43  Not Placed
# 4     No     96.8        Mkt&Fin  55.50      Placed

# %%
sns.countplot(data=df,x='hsc_s')
# Out:
# <Axes: xlabel='hsc_s', ylabel='count'>

# %%
df.describe(include='all')
# Out:
#        gender       ssc_p    ssc_b       hsc_p   hsc_b     hsc_s    degree_p  \
# count     215  215.000000      215  215.000000     215       215  215.000000
# unique      2         NaN        2         NaN       2         3         NaN
# top         M         NaN  Central         NaN  Others  Commerce         NaN
# freq      139         NaN      116         NaN     131       113         NaN
# mean      NaN   67.303395      NaN   66.333163     NaN       NaN   66.370186
# std       NaN   10.827205      NaN   10.897509     NaN       NaN    7.358743
# min       NaN   40.890000      NaN   37.000000     NaN       NaN   50.000000
# 25%       NaN   60.600000      NaN   60.900000     NaN       NaN   61.000000
# 50%       NaN   67.000000      NaN   65.000000     NaN       NaN   66.000000
# 75%       NaN   75.700000      NaN   73.000000     NaN       NaN   72.000000
# max       NaN   89.400000      NaN   97.700000     NaN       NaN   91.000000
#
# ...

# %%
df.corr()
# Out:
# C:\Users\ayush\AppData\Local\Temp\ipykernel_22236\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#              ssc_p     hsc_p  degree_p   etest_p     mba_p
# ssc_p     1.000000  0.511472  0.538404  0.261993  0.388478
# hsc_p     0.511472  1.000000  0.434206  0.245113  0.354823
# degree_p  0.538404  0.434206  1.000000  0.224470  0.402364
# etest_p   0.261993  0.245113  0.224470  1.000000  0.218055
# mba_p     0.388478  0.354823  0.402364  0.218055  1.000000

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
sns.boxplot(data=df,x='degree_p' , y='hsc_s')
# Out:
# <Axes: xlabel='degree_p', ylabel='hsc_s'>

# %%
sns.pairplot(data=df, vars=['ssc_p','hsc_p'], hue='status');

# %%
sns.histplot(data=df,x='degree_p' , hue='status',kde=True)
# Out:
# <Axes: xlabel='degree_p', ylabel='Count'>

# %%
df.describe(include='all')
# Out:
#        gender       ssc_p    ssc_b       hsc_p   hsc_b     hsc_s    degree_p  \
# count     215  215.000000      215  215.000000     215       215  215.000000
# unique      2         NaN        2         NaN       2         3         NaN
# top         M         NaN  Central         NaN  Others  Commerce         NaN
# freq      139         NaN      116         NaN     131       113         NaN
# mean      NaN   67.303395      NaN   66.333163     NaN       NaN   66.370186
# std       NaN   10.827205      NaN   10.897509     NaN       NaN    7.358743
# min       NaN   40.890000      NaN   37.000000     NaN       NaN   50.000000
# 25%       NaN   60.600000      NaN   60.900000     NaN       NaN   61.000000
# 50%       NaN   67.000000      NaN   65.000000     NaN       NaN   66.000000
# 75%       NaN   75.700000      NaN   73.000000     NaN       NaN   72.000000
# max       NaN   89.400000      NaN   97.700000     NaN       NaN   91.000000
#
# ...

# %%
not_placed = df[df['status'] =='Not Placed']
len(not_placed)
# Out:
# 67

# %%
len(not_placed[not_placed['ssc_p'] < 65])
# Out:
# 55

# %%
less_p = (len(not_placed[not_placed['ssc_p'] < 65])/len(not_placed))*100
less_p
# Out:
# 82.08955223880598

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
sns.boxplot(data=df,x='degree_t' , y='degree_p', hue='status')
# Out:
# <Axes: xlabel='degree_t', ylabel='degree_p'>

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
sns.violinplot(data=df,x='degree_p', y = 'specialisation');

# %%
sns.jointplot(data=df,x='ssc_p',y='degree_p',kind='hex');
plt.colorbar(); # This adds a vertical color bar to measure the color scale

# %%
sns.histplot(data=df,x='ssc_p' , kde=True)
# Out:
# <Axes: xlabel='ssc_p', ylabel='Count'>

# %%
df.head(3)
# Out:
#   gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \
# 0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech
# 1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech
# 2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt
#
#   workex  etest_p specialisation  mba_p  status
# 0     No     55.0         Mkt&HR  58.80  Placed
# 1    Yes     86.5        Mkt&Fin  66.28  Placed
# 2     No     75.0        Mkt&Fin  57.80  Placed

# %%
sns.histplot(data=df,x='etest_p' , kde=True)
# Out:
# <Axes: xlabel='etest_p', ylabel='Count'>

# %%
df['etest_p'].max()
# Out:
# 98.0
